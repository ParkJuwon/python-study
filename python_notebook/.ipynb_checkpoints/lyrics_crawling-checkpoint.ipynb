# %%
from bs4 import BeautifulSoup
import requests
import re
import time

# %%
# https://www.lyrics.co.kr/?p=609525

# 제목
# h1 page-header fa fa-align-justify
# <title>

# 가사
# div box-body font_size_up

url='https://www.lyrics.co.kr/?p={}'


music_list = []
with open("music_list.txt", "w") as f:
    for page_no in range(571176, 0, -1):
        if page_no % 100 == 0:
            print('1 sec sleep.... current page_no : {}'.format(page_no))
            time.sleep(1)

        resp = requests.get(url.format(page_no))
        soup = BeautifulSoup(resp.text)

        title = soup.find('title')
        lyrics = soup.select('body > div > div > section > div > div.col-md-8.col-sm-7 > div > div > div.box-body.font_size_up')

        if title and lyrics:
            music_name = title.get_text().split('|')[0].strip()
            music_name = re.sub(r'[\s]*[(][+][)][\s]*', '$$$', music_name)
            music_lyrics = lyrics[0].text.strip()
            music_lyrics = re.sub(r'\r\n', ' ', music_lyrics)
            music_lyrics = re.sub(r'\n', ' ', music_lyrics)
            music = music_name + '$$$' + music_lyrics
            f.write(music + '\n')

print('done')

#571177 까지 읽음
# Out:
# 1 sec sleep.... current page_no : 609500
# 1 sec sleep.... current page_no : 609400
# 1 sec sleep.... current page_no : 609300
# 1 sec sleep.... current page_no : 609200
# 1 sec sleep.... current page_no : 609100
# 1 sec sleep.... current page_no : 609000
# 1 sec sleep.... current page_no : 608900
# 1 sec sleep.... current page_no : 608800
# 1 sec sleep.... current page_no : 608700
# 1 sec sleep.... current page_no : 608600
# 1 sec sleep.... current page_no : 608500
# 1 sec sleep.... current page_no : 608400
# 1 sec sleep.... current page_no : 608300
# 1 sec sleep.... current page_no : 608200
# 1 sec sleep.... current page_no : 608100
# 1 sec sleep.... current page_no : 608000
# 1 sec sleep.... current page_no : 607900
# 1 sec sleep.... current page_no : 607800
# 1 sec sleep.... current page_no : 607700
# 1 sec sleep.... current page_no : 607600
# 1 sec sleep.... current page_no : 607500
# 1 sec sleep.... current page_no : 607400
# 1 sec sleep.... current page_no : 607300
# 1 sec sleep.... current page_no : 607200
# 1 sec sleep.... current page_no : 607100
# 1 sec sleep.... current page_no : 607000
# 1 sec sleep.... current page_no : 606900
# 1 sec sleep.... current page_no : 606800
# 1 sec sleep.... current page_no : 606700
# 1 sec sleep.... current page_no : 606600
# 1 sec sleep.... current page_no : 606500
# 1 sec sleep.... current page_no : 606400
# 1 sec sleep.... current page_no : 606300
# 1 sec sleep.... current page_no : 606200
# 1 sec sleep.... current page_no : 606100
# 1 sec sleep.... current page_no : 606000
# 1 sec sleep.... current page_no : 605900
# 1 sec sleep.... current page_no : 605800
# 1 sec sleep.... current page_no : 605700
# 1 sec sleep.... current page_no : 605600
# 1 sec sleep.... current page_no : 605500
# 1 sec sleep.... current page_no : 605400
# 1 sec sleep.... current page_no : 605300
# 1 sec sleep.... current page_no : 605200
# 1 sec sleep.... current page_no : 605100
# 1 sec sleep.... current page_no : 605000
# 1 sec sleep.... current page_no : 604900
# 1 sec sleep.... current page_no : 604800
# 1 sec sleep.... current page_no : 604700
# 1 sec sleep.... current page_no : 604600
# 1 sec sleep.... current page_no : 604500
# 1 sec sleep.... current page_no : 604400
# 1 sec sleep.... current page_no : 604300
# 1 sec sleep.... current page_no : 604200
# 1 sec sleep.... current page_no : 604100
# 1 sec sleep.... current page_no : 604000
# 1 sec sleep.... current page_no : 603900
# 1 sec sleep.... current page_no : 603800
# 1 sec sleep.... current page_no : 603700
# 1 sec sleep.... current page_no : 603600
# 1 sec sleep.... current page_no : 603500
# 1 sec sleep.... current page_no : 603400
# 1 sec sleep.... current page_no : 603300
# 1 sec sleep.... current page_no : 603200
# 1 sec sleep.... current page_no : 603100
# 1 sec sleep.... current page_no : 603000
# 1 sec sleep.... current page_no : 602900
# 1 sec sleep.... current page_no : 602800
# 1 sec sleep.... current page_no : 602700
# 1 sec sleep.... current page_no : 602600
# 1 sec sleep.... current page_no : 602500
# 1 sec sleep.... current page_no : 602400
# 1 sec sleep.... current page_no : 602300
# 1 sec sleep.... current page_no : 602200
# 1 sec sleep.... current page_no : 602100
# 1 sec sleep.... current page_no : 602000
# 1 sec sleep.... current page_no : 601900
# 1 sec sleep.... current page_no : 601800
# 1 sec sleep.... current page_no : 601700
# 1 sec sleep.... current page_no : 601600
# 1 sec sleep.... current page_no : 601500
# 1 sec sleep.... current page_no : 601400
# 1 sec sleep.... current page_no : 601300
# 1 sec sleep.... current page_no : 601200
# 1 sec sleep.... current page_no : 601100
# 1 sec sleep.... current page_no : 601000
# 1 sec sleep.... current page_no : 600900
# 1 sec sleep.... current page_no : 600800
# 1 sec sleep.... current page_no : 600700
# 1 sec sleep.... current page_no : 600600
# 1 sec sleep.... current page_no : 600500
# 1 sec sleep.... current page_no : 600400
# 1 sec sleep.... current page_no : 600300
# 1 sec sleep.... current page_no : 600200
# 1 sec sleep.... current page_no : 600100
# 1 sec sleep.... current page_no : 600000
# 1 sec sleep.... current page_no : 599900
# 1 sec sleep.... current page_no : 599800
# 1 sec sleep.... current page_no : 599700
# 1 sec sleep.... current page_no : 599600
# 1 sec sleep.... current page_no : 599500
# 1 sec sleep.... current page_no : 599400
# 1 sec sleep.... current page_no : 599300
# 1 sec sleep.... current page_no : 599200
# 1 sec sleep.... current page_no : 599100
# 1 sec sleep.... current page_no : 599000
# 1 sec sleep.... current page_no : 598900
# 1 sec sleep.... current page_no : 598800
# 1 sec sleep.... current page_no : 598700
# 1 sec sleep.... current page_no : 598600
# 1 sec sleep.... current page_no : 598500
# 1 sec sleep.... current page_no : 598400
# 1 sec sleep.... current page_no : 598300
# 1 sec sleep.... current page_no : 598200
# 1 sec sleep.... current page_no : 598100
# 1 sec sleep.... current page_no : 598000
# 1 sec sleep.... current page_no : 597900
# 1 sec sleep.... current page_no : 597800
# 1 sec sleep.... current page_no : 597700
# 1 sec sleep.... current page_no : 597600
# 1 sec sleep.... current page_no : 597500
# 1 sec sleep.... current page_no : 597400
# 1 sec sleep.... current page_no : 597300
# 1 sec sleep.... current page_no : 597200
# 1 sec sleep.... current page_no : 597100
# 1 sec sleep.... current page_no : 597000
# 1 sec sleep.... current page_no : 596900
# 1 sec sleep.... current page_no : 596800
# 1 sec sleep.... current page_no : 596700
# 1 sec sleep.... current page_no : 596600
# 1 sec sleep.... current page_no : 596500
# 1 sec sleep.... current page_no : 596400
# 1 sec sleep.... current page_no : 596300
# 1 sec sleep.... current page_no : 596200
# 1 sec sleep.... current page_no : 596100
# 1 sec sleep.... current page_no : 596000
# 1 sec sleep.... current page_no : 595900
# 1 sec sleep.... current page_no : 595800
# 1 sec sleep.... current page_no : 595700
# 1 sec sleep.... current page_no : 595600
# 1 sec sleep.... current page_no : 595500
# 1 sec sleep.... current page_no : 595400
# 1 sec sleep.... current page_no : 595300
# 1 sec sleep.... current page_no : 595200
# 1 sec sleep.... current page_no : 595100
# 1 sec sleep.... current page_no : 595000
# 1 sec sleep.... current page_no : 594900
# 1 sec sleep.... current page_no : 594800
# 1 sec sleep.... current page_no : 594700
# 1 sec sleep.... current page_no : 594600
# 1 sec sleep.... current page_no : 594500
# 1 sec sleep.... current page_no : 594400
# 1 sec sleep.... current page_no : 594300
# 1 sec sleep.... current page_no : 594200
# 1 sec sleep.... current page_no : 594100
# 1 sec sleep.... current page_no : 594000
# 1 sec sleep.... current page_no : 593900
# 1 sec sleep.... current page_no : 593800
# 1 sec sleep.... current page_no : 593700
# 1 sec sleep.... current page_no : 593600
# 1 sec sleep.... current page_no : 593500
# 1 sec sleep.... current page_no : 593400
# 1 sec sleep.... current page_no : 593300
# 1 sec sleep.... current page_no : 593200
# 1 sec sleep.... current page_no : 593100
# 1 sec sleep.... current page_no : 593000
# 1 sec sleep.... current page_no : 592900
# 1 sec sleep.... current page_no : 592800
# 1 sec sleep.... current page_no : 592700
# 1 sec sleep.... current page_no : 592600
# 1 sec sleep.... current page_no : 592500
# 1 sec sleep.... current page_no : 592400
# 1 sec sleep.... current page_no : 592300
# 1 sec sleep.... current page_no : 592200
# 1 sec sleep.... current page_no : 592100
# 1 sec sleep.... current page_no : 592000
# 1 sec sleep.... current page_no : 591900
# 1 sec sleep.... current page_no : 591800
# 1 sec sleep.... current page_no : 591700
# 1 sec sleep.... current page_no : 591600
# 1 sec sleep.... current page_no : 591500
# 1 sec sleep.... current page_no : 591400
# 1 sec sleep.... current page_no : 591300
# 1 sec sleep.... current page_no : 591200
# 1 sec sleep.... current page_no : 591100
# 1 sec sleep.... current page_no : 591000
# 1 sec sleep.... current page_no : 590900
# 1 sec sleep.... current page_no : 590800
# 1 sec sleep.... current page_no : 590700
# 1 sec sleep.... current page_no : 590600
# 1 sec sleep.... current page_no : 590500
# 1 sec sleep.... current page_no : 590400
# 1 sec sleep.... current page_no : 590300
# 1 sec sleep.... current page_no : 590200
# 1 sec sleep.... current page_no : 590100
# 1 sec sleep.... current page_no : 590000
# 1 sec sleep.... current page_no : 589900
# 1 sec sleep.... current page_no : 589800
# 1 sec sleep.... current page_no : 589700
# 1 sec sleep.... current page_no : 589600
# 1 sec sleep.... current page_no : 589500
# 1 sec sleep.... current page_no : 589400
# 1 sec sleep.... current page_no : 589300
# 1 sec sleep.... current page_no : 589200
# 1 sec sleep.... current page_no : 589100
# 1 sec sleep.... current page_no : 589000
# 1 sec sleep.... current page_no : 588900
# 1 sec sleep.... current page_no : 588800
# 1 sec sleep.... current page_no : 588700
# 1 sec sleep.... current page_no : 588600
# 1 sec sleep.... current page_no : 588500
# 1 sec sleep.... current page_no : 588400
# 1 sec sleep.... current page_no : 588300
# 1 sec sleep.... current page_no : 588200
# 1 sec sleep.... current page_no : 588100
# 1 sec sleep.... current page_no : 588000
# 1 sec sleep.... current page_no : 587900
# 1 sec sleep.... current page_no : 587800
# 1 sec sleep.... current page_no : 587700
# 1 sec sleep.... current page_no : 587600
# 1 sec sleep.... current page_no : 587500
# 1 sec sleep.... current page_no : 587400
# 1 sec sleep.... current page_no : 587300
# 1 sec sleep.... current page_no : 587200
# 1 sec sleep.... current page_no : 587100
# 1 sec sleep.... current page_no : 587000
# 1 sec sleep.... current page_no : 586900
# 1 sec sleep.... current page_no : 586800
# 1 sec sleep.... current page_no : 586700
# 1 sec sleep.... current page_no : 586600
# 1 sec sleep.... current page_no : 586500
# 1 sec sleep.... current page_no : 586400
# 1 sec sleep.... current page_no : 586300
# 1 sec sleep.... current page_no : 586200
# 1 sec sleep.... current page_no : 586100
# 1 sec sleep.... current page_no : 586000
# 1 sec sleep.... current page_no : 585900
# 1 sec sleep.... current page_no : 585800
# 1 sec sleep.... current page_no : 585700
# 1 sec sleep.... current page_no : 585600
# 1 sec sleep.... current page_no : 585500
# 1 sec sleep.... current page_no : 585400
# 1 sec sleep.... current page_no : 585300
# 1 sec sleep.... current page_no : 585200
# 1 sec sleep.... current page_no : 585100
# 1 sec sleep.... current page_no : 585000
# 1 sec sleep.... current page_no : 584900
# 1 sec sleep.... current page_no : 584800
# 1 sec sleep.... current page_no : 584700
# 1 sec sleep.... current page_no : 584600
# 1 sec sleep.... current page_no : 584500
# 1 sec sleep.... current page_no : 584400
# 1 sec sleep.... current page_no : 584300
# 1 sec sleep.... current page_no : 584200
# 1 sec sleep.... current page_no : 584100
# 1 sec sleep.... current page_no : 584000
# 1 sec sleep.... current page_no : 583900
# 1 sec sleep.... current page_no : 583800
# 1 sec sleep.... current page_no : 583700
# 1 sec sleep.... current page_no : 583600
# 1 sec sleep.... current page_no : 583500
# 1 sec sleep.... current page_no : 583400
# 1 sec sleep.... current page_no : 583300
# 1 sec sleep.... current page_no : 583200
# 1 sec sleep.... current page_no : 583100
# 1 sec sleep.... current page_no : 583000
# 1 sec sleep.... current page_no : 582900
# 1 sec sleep.... current page_no : 582800
# 1 sec sleep.... current page_no : 582700
# 1 sec sleep.... current page_no : 582600
# 1 sec sleep.... current page_no : 582500
# 1 sec sleep.... current page_no : 582400
# 1 sec sleep.... current page_no : 582300
# 1 sec sleep.... current page_no : 582200
# 1 sec sleep.... current page_no : 582100
# 1 sec sleep.... current page_no : 582000
# 1 sec sleep.... current page_no : 581900
# 1 sec sleep.... current page_no : 581800
# 1 sec sleep.... current page_no : 581700
# 1 sec sleep.... current page_no : 581600
# 1 sec sleep.... current page_no : 581500
# 1 sec sleep.... current page_no : 581400
# 1 sec sleep.... current page_no : 581300
# 1 sec sleep.... current page_no : 581200
# 1 sec sleep.... current page_no : 581100
# 1 sec sleep.... current page_no : 581000
# 1 sec sleep.... current page_no : 580900
# 1 sec sleep.... current page_no : 580800
# 1 sec sleep.... current page_no : 580700
# 1 sec sleep.... current page_no : 580600
# 1 sec sleep.... current page_no : 580500
# 1 sec sleep.... current page_no : 580400
# 1 sec sleep.... current page_no : 580300
# 1 sec sleep.... current page_no : 580200
# 1 sec sleep.... current page_no : 580100
# 1 sec sleep.... current page_no : 580000
# 1 sec sleep.... current page_no : 579900
# 1 sec sleep.... current page_no : 579800
# 1 sec sleep.... current page_no : 579700
# 1 sec sleep.... current page_no : 579600
# 1 sec sleep.... current page_no : 579500
# 1 sec sleep.... current page_no : 579400
# 1 sec sleep.... current page_no : 579300
# 1 sec sleep.... current page_no : 579200
# 1 sec sleep.... current page_no : 579100
# 1 sec sleep.... current page_no : 579000
# 1 sec sleep.... current page_no : 578900
# 1 sec sleep.... current page_no : 578800
# 1 sec sleep.... current page_no : 578700
# 1 sec sleep.... current page_no : 578600
# 1 sec sleep.... current page_no : 578500
# 1 sec sleep.... current page_no : 578400
# 1 sec sleep.... current page_no : 578300
# 1 sec sleep.... current page_no : 578200
# 1 sec sleep.... current page_no : 578100
# 1 sec sleep.... current page_no : 578000
# 1 sec sleep.... current page_no : 577900
# 1 sec sleep.... current page_no : 577800
# 1 sec sleep.... current page_no : 577700
# 1 sec sleep.... current page_no : 577600
# 1 sec sleep.... current page_no : 577500
# 1 sec sleep.... current page_no : 577400
# 1 sec sleep.... current page_no : 577300
# 1 sec sleep.... current page_no : 577200
# 1 sec sleep.... current page_no : 577100
# 1 sec sleep.... current page_no : 577000
# 1 sec sleep.... current page_no : 576900
# 1 sec sleep.... current page_no : 576800
# 1 sec sleep.... current page_no : 576700
# 1 sec sleep.... current page_no : 576600
# 1 sec sleep.... current page_no : 576500
# 1 sec sleep.... current page_no : 576400
# 1 sec sleep.... current page_no : 576300
# 1 sec sleep.... current page_no : 576200
# 1 sec sleep.... current page_no : 576100
# 1 sec sleep.... current page_no : 576000
# 1 sec sleep.... current page_no : 575900
# 1 sec sleep.... current page_no : 575800
# 1 sec sleep.... current page_no : 575700
# 1 sec sleep.... current page_no : 575600
# 1 sec sleep.... current page_no : 575500
# 1 sec sleep.... current page_no : 575400
# 1 sec sleep.... current page_no : 575300
# 1 sec sleep.... current page_no : 575200
# 1 sec sleep.... current page_no : 575100
# 1 sec sleep.... current page_no : 575000
# 1 sec sleep.... current page_no : 574900
# 1 sec sleep.... current page_no : 574800
# 1 sec sleep.... current page_no : 574700
# 1 sec sleep.... current page_no : 574600
# 1 sec sleep.... current page_no : 574500
# 1 sec sleep.... current page_no : 574400
# 1 sec sleep.... current page_no : 574300
# 1 sec sleep.... current page_no : 574200
# 1 sec sleep.... current page_no : 574100
# 1 sec sleep.... current page_no : 574000
# 1 sec sleep.... current page_no : 573900
# 1 sec sleep.... current page_no : 573800
# 1 sec sleep.... current page_no : 573700
# 1 sec sleep.... current page_no : 573600
# 1 sec sleep.... current page_no : 573500
# 1 sec sleep.... current page_no : 573400
# 1 sec sleep.... current page_no : 573300
# 1 sec sleep.... current page_no : 573200
# 1 sec sleep.... current page_no : 573100
# 1 sec sleep.... current page_no : 573000
# 1 sec sleep.... current page_no : 572900
# 1 sec sleep.... current page_no : 572800
# 1 sec sleep.... current page_no : 572700
# 1 sec sleep.... current page_no : 572600
# 1 sec sleep.... current page_no : 572500
# 1 sec sleep.... current page_no : 572400
# 1 sec sleep.... current page_no : 572300
# 1 sec sleep.... current page_no : 572200
# 1 sec sleep.... current page_no : 572100
# 1 sec sleep.... current page_no : 572000
# 1 sec sleep.... current page_no : 571900
# 1 sec sleep.... current page_no : 571800
# 1 sec sleep.... current page_no : 571700
# 1 sec sleep.... current page_no : 571600
# 1 sec sleep.... current page_no : 571500
# 1 sec sleep.... current page_no : 571400
# 1 sec sleep.... current page_no : 571300
# 1 sec sleep.... current page_no : 571200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-7c42d988630e> in <module>
#      18             time.sleep(1)
#      19
# ---> 20         resp = requests.get(url.format(page_no))
#      21         soup = BeautifulSoup(resp.text)
#      22
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     342             or IS_SECURETRANSPORT):
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#     346         warnings.warn(
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     451         while True:
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1912         :return: None.
#    1913         """
# -> 1914         result = _lib.SSL_do_handshake(self._ssl)
#    1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# KeyboardInterrupt:
